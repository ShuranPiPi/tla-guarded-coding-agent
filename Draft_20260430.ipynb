# %%
"""End-to-end demo: run the agent on one sample task and print the trace."""
from __future__ import annotations
import json
import sys
from pathlib import Path
from dotenv import load_dotenv  # noqa: E402
from agent import run_agent  # noqa: E402

# %%
# Make ``agent`` importable when running this file directly.
# sys.path.insert(0, str(Path(__file__).resolve().parent.parent))
load_dotenv()
# TASKS_PATH = Path(__file__).resolve().parent.parent / "tasks" / "sample_tasks.json"
TASKS_PATH = "./tasks/sample_tasks.json"

# %%
# from openai import OpenAI

# client = OpenAI(
#   api_key="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"
# )

# response = client.responses.create(
#   model="gpt-5.4-mini",
#   input="write a haiku about ai",
#   store=True,
# )

# print(response.output_text)

# %%
def main(task_name: str = "two_sum") -> None:
    tasks = json.load(open(TASKS_PATH, 'r'))
    task = next((t for t in tasks if t["name"] == task_name), tasks[0])

    print(f"=== Running agent on task: {task['name']} ===\n")
    final = run_agent(task, max_retries=3)

    print("--- Trace ---")
    for line in final["history"]:
        print(" ", line)

    print("\n--- Spec ---")
    print(" ", final["tlaSpec"])

    print("\n--- Final workflow state ---")
    print(" ", final["workflow"])
    
    print("\n--- Final code ---")
    print(final["code"])
    print("\n--- Retries used ---", final["retries"])



main("column_maximim_strategy")
# Out:
# === Running agent on task: column_maximim_strategy ===
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[8], line 24
#      19     print(final["code"])
#      20     print("\n--- Retries used ---", final["retries"])
# ---> 24 main("column_maximim_strategy")
#
# Cell In[8], line 6, in main(task_name)
#       3 task = next((t for t in tasks if t["name"] == task_name), tasks[0])
#       5 print(f"=== Running agent on task: {task['name']} ===\n")
# ----> 6 final = run_agent(task, max_retries=3)
#       8 print("--- Trace ---")
#       9 for line in final["history"]:
#
# File e:\Work\Northwestern\q3\356\Project_Draft\tla-guarded-coding-agent-main\agent\graph.py:73, in run_agent(task, max_retries)
#      58 initial: AgentState = {
#      59     "problem": task["problem"],
#      60     "signature": task["signature"],
#    (...)     69     "history": [],
#      70 }
# ...
